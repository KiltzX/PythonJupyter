# %%
import numpy
import matplotlib.pyplot as plt

# %%
numpy.random.seed(5)

# %%
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

# %%
plt.scatter(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %%
numpy.random.seed(3)

# %%
x = numpy.random.normal(3, 1, 100)
y = numpy.random.normal(150, 40, 100) / x

# %%
plt.scatter(x, y)
plt.show()

# %%
x = numpy.random.normal(3, 1, 150)
y = numpy.random.normal(150, 40, 1) * x

# %%
plt.scatter(x, y)
plt.show()

# %%
x = numpy.random.normal(3, 1, 150)
y = numpy.random.normal(150, 40, 1) * x

# %%
plt.scatter(x, y)
plt.show()
